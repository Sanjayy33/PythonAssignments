# %% [markdown]
# <h1>Task 1</h1>

# %%
item_price = 256
delivery_fee = 23
coupon_discount = 18
print(item_price)
print(delivery_fee)
print(coupon_discount)
# Out:
# 256
# 23
# 18

# %% [markdown]
# <h1>Task 2</h1>

# %%
product_price = int(input("Enter Product Price : "))
if (product_price >= 1000):
    print("free delivery")
    print(f"total bill : {product_price}")
else:
    print("30 delivery charge add")
    print(f"total bill : {product_price + 30}")
# Out:
# Enter Product Price :  680
# 30 delivery charge add
# total bill : 710

# %% [markdown]
# <h1>Task 3</h1>

# %%
# taking number from user and print table
number = int(input("Enter number : ")) # takng input from user
for i in range(1,11): #run loop from 1 to 10
    print(number, " x ", i, " = ", number*i)

"""
in for loop i store two value first starting value 1 
to ending value 10 and increase +1 in starting value.
print() fuction console value that given inside.
number where user alredy enter, i sotre in for by range function
and number * i = 5 * 1 when run first time 
number * i = 5 * 2 when run second third time
number * i = 5 * 3 when run third time
*
*
*
number * i = 5 * 10 when run ten time.
"""
# Out:
# Enter number :  10
# 10  x  1  =  10
# 10  x  2  =  20
# 10  x  3  =  30
# 10  x  4  =  40
# 10  x  5  =  50
# 10  x  6  =  60
# 10  x  7  =  70
# 10  x  8  =  80
# 10  x  9  =  90
# 10  x  10  =  100
# '\nin for loop i store two value first starting value 1 \nto ending value 10 and increase +1 in starting value.\nprint() fuction console value that given inside.\nnumber where user alredy enter, i sotre in for by range function\nand number * i = 5 * 1 when run first time \nnumber * i = 5 * 2 when run second third time\nnumber * i = 5 * 3 when run third time\n*\n*\n*\nnumber * i = 5 * 10 when run ten time.\n'

# %% [markdown]
# <h1>Task 4</h1>

# %%
team_name = "csk"
runs_scored = 218
overs_played = 19.4 # all out
print(team_name)
print(runs_scored)
print(overs_played)
# Out:
# csk
# 218
# 19.4
