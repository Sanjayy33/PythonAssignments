# %% [markdown]
# <h1>Task 1</h1>

# %%
print("Vanzara Sanjay")
print("I like ChatGPT")
# Out:
# Vanzara Sanjay
# I like ChatGPT

# %% [markdown]
# <h1>Task 2</h1>

# %%
print('Welcome to Data Science with Python')
# Out:
# Welcome to Data Science with Python
