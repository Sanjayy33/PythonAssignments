# %% [markdown]
# <h1>Task 1</h1>

# %%
listening_time = int(input("Enter your current song listening time in min : "))
if listening_time > 120:
    print("You are a true listening fan!")
else:
    print("Keep listening!")
# Out:
# Enter your current song listening time in min :  121
# You are a true listening fan!

# %% [markdown]
# <h1>Task 2</h1>

# %%
order_amount = int(input("Enter your zomato order amount :"))
if order_amount > 300:
    print("Eligible for free delivery")
else:
    print("Delivery charge apply")
# Out:
# Enter your zomato order amount : 399
# Eligible for free delivery

# %% [markdown]
# <h1>Task 3</h1>

# %%
flipkart_total = int(input("Enter total amount : "))
if flipkart_total > 2000:
    print("You get 10% discount")
elif flipkart_total > 1000:
    print("You get 5% discount")
else:
    print("No discount avaliable")
# Out:
# Enter total amount :  1999
# You get 5% discount

# %% [markdown]
# <h1>Task 4</h1>

# %%
team_point = int(input("Enter your IPL team point : "))
if team_point > 800:
    print("Champion")
else:
    if team_point > 500 and team_point < 800:
        print("Top perfomer")
    else:
        print("Keep trying")
# Out:
# Enter your IPL team point :  499
# Keep trying
