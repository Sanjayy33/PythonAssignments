# %% [markdown]
# <h1>Task 1</h1>

# %%
string =  'Flipkart-Sale2024'
low_str = string.lower()
replace_str = string.replace('-',' ')
string = string.lower()
string = string.replace('-',' ')
print(low_str)
print(replace_str)
print(string)
# Out:
# flipkart-sale2024
# Flipkart Sale2024
# flipkart sale2024

# %% [markdown]
# <h1>Task 2</h1>

# %%
product_name =  ' OnePlus Nord-CE 3 '
rmv_space = product_name.strip()
upcase_str = product_name.upper()
replace_str = product_name.replace('-',',')
print(rmv_space)
print(upcase_str)
print(replace_str)
# Out:
# OnePlus Nord-CE 3
#  ONEPLUS NORD-CE 3
#  OnePlus Nord,CE 3

# %% [markdown]
# <h1>Task 3</h1>

# %%
def split_product_code(product_code):
    # replace_str = product_code.replace("-"," ")
    split_str = product_code.split("-")
    return split_str
product_code = 'ZOMATO-FOOD-2024'
print(split_product_code(product_code))
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %% [markdown]
# <h1>Task 4</h1>

# %%
string = 'Spotify_Premium_Offer'
print(string[8:15])
# Out:
# Premium

# %% [markdown]
# <h1>Task 5</h1>

# %%
product = 'Myntra Shirt'
price = 799.5
# print(f"Deal: {product} is available at ₹{price} only!")
print("Deal: {product_name} is available at ₹{product_price} only!".format(
    product_name = product,
    product_price = price
))
# Out:
# Deal: Myntra Shirt is available at ₹799.5 only!
