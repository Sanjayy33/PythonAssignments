# %% [markdown]
# <h1>Task 1</h1>

# %%
playlist_ids = [87,33,67,18,34]
# print(playlist_ids)
for i in range(len(playlist_ids)):
    print(playlist_ids[i])
# Out:
# 87
# 33
# 67
# 18
# 34

# %% [markdown]
# <h1>Task 2</h1>

# %%
second_plylist_ids = [56,37,22,78]
playlist_ids.append(3)
print(playlist_ids)
playlist_ids.extend(second_plylist_ids)
print(playlist_ids)
# Out:
# [87, 33, 67, 18, 34, 3]
# [87, 33, 67, 18, 34, 3, 56, 37, 22, 78]

# %% [markdown]
# <h1>Task 3</h1>

# %%
playlist_ids = [87,33,67,18,34]
print(playlist_ids.pop())
print(playlist_ids)
# Out:
# 34
# [87, 33, 67, 18]

# %% [markdown]
# <h1>Task 4</h1>

# %%
insta_filters = ("black and white", "blur", "moon light", "butterfly effect")
insta_filters[0] = "black&white"
print(insta_filters)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 insta_filters = ("black and white", "blur", "moon light", "butterfly effect")
# ----> 2 insta_filters[0] = "black&white"
#       3 print(insta_filters)
#
# TypeError: 'tuple' object does not support item assignment
